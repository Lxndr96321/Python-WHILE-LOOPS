# %% [markdown]
# In \[ \]:
#
#
#
# In \[8\]:
#
#     x=float(input("enter your marks:"))
#     if x>=35:
#         print("congo..you passed")
#     else:
#         print("better up luck next time")
#
#     enter your marks:88
#     congo..you passed
#
# In \[6\]:
#
#     x=int(input("enter a number:"))
#     if x%2==0:
#         print("it is a even number")
#     else:
#         print("number is odd")
#
#     enter a number:4
#     it is a even number
#
# In \[ \]:
#
#     wap accepts mark student greter 85 print 1st cls
#     greter 40 2nd
#     less 40 fail
#
# In \[10\]:
#
#     x=float(input("enter your marks:"))
#     if x>=85:
#         print("congo..you  scored 1st class")
#     elif x>=40 and x<85:
#         print("congo..you  scored 2nd class")
#     else:
#         print("better up luck next time")
#
#     enter your marks:45
#     congo..you  scored 2nd class
#
# In \[15\]:
#
#     x=float(input("enter your marks:"))
#     if x>=85:
#         print("congo..you  scored 1st class")
#     elif x>=60 and x<85:
#         print("congo..you  scored 2nd class")
#     elif x>=40 and x<60:
#         print("congo..you  scored 3rd class")
#     else:
#         print("better up luck next time")
#
#     enter your marks:60
#     congo..you  scored 2nd class
#
# In \[ \]:
#
#     wap  accept a num and a string from user cheack the oval and number is even or odd
#
# In \[25\]:
#
#     x=input("Enter a string:").lower()
#     y=int(input("enter your marks:"))
#     vowels=['a','e','i','o','u']
#     if x[0]in vowels and y%2==0:
#         print("String starts with oval and the number is even ")
#     elif x[0]not in vowels and y%2==0:
#         print("String not starts with oval and the number is even ")
#     elif x[0] in vowels and y%2!=0:
#         print("String starts with oval and the number is not even ")
#     else:
#         print("it is not start with oval and it is a odd number")
#
#     Enter a string:sai
#     enter your marks:5
#     it is not start with oval and it is a odd number
#
# In \[34\]:
#
#     x=int(input("Enter a string:"))
#     while x%2==0:
#         print("end")
#         x+=1
#
#     Enter a string:4
#     end
#     end1
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
